# %%
pip install omdb
# Out:
# Requirement already satisfied: omdb in c:\users\robin\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: requests>=2.0.1 in c:\users\robin\anaconda3\lib\site-packages (from omdb) (2.22.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\robin\anaconda3\lib\site-packages (from requests>=2.0.1->omdb) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\robin\anaconda3\lib\site-packages (from requests>=2.0.1->omdb) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\robin\anaconda3\lib\site-packages (from requests>=2.0.1->omdb) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\robin\anaconda3\lib\site-packages (from requests>=2.0.1->omdb) (2019.6.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
import omdb
import os
import pandas as pd
import numpy as np
import requests

omdb.set_default('apikey', "14331679")

# %%
df = pd.read_csv('movies_2018.csv',encoding='latin-1')
df.columns={"Title"}

# %%
# Module for reading CSV files

films = df["Title"]
titles = []
metascore = []
ratings = []
runtime = []
released = []
genre = []
box_office = []

record = 1
notfound = 0
found = 0
total = len(df)
j = 0

for film in films:
    try:
        response = omdb.get(title={film})
        titles.append(response["title"])
        metascore.append(response["metascore"])
        ratings.append(response["rated"])
        runtime.append(response["runtime"])
        released.append(response["released"])
        genre.append(response["genre"])
        box_office.append(response["box_office"])
        j += 1
        record += 1
        found += 1
        print(f"Processing Record {j} of {total} | {film}")
    except Exception:
        print(f"Processing Record {j} of {total} | {film} not found - skipping.")
        record += 1
        notfound += 1
        
pct_movie_found = round(found/(notfound+found)*100,1)       
print(f"{pct_movie_found}% of movies found")
# Out:
# Processing Record 1 of 268 | The Strange Ones
# Processing Record 2 of 268 | Stratton
# Processing Record 3 of 268 | Sweet Country
# Processing Record 4 of 268 | The Commuter
# Processing Record 5 of 268 | Proud Mary
# Processing Record 6 of 268 | Acts of Violence
# Processing Record 7 of 268 | Freak Show
# Processing Record 8 of 268 | Humor Me
# Processing Record 9 of 268 | Vazante
# Processing Record 10 of 268 | Mary and the Witch's Flower
# Processing Record 11 of 268 | 12 Strong
# Processing Record 12 of 268 | Den of Thieves
# Processing Record 13 of 268 | Forever My Girl
# Processing Record 14 of 268 | Maze Runner: The Death Cure
# Processing Record 15 of 268 | The Insult
# Processing Record 16 of 268 | Please Stand By
# Processing Record 17 of 268 | Winchester
# Processing Record 18 of 268 | A Fantastic Woman
# Processing Record 19 of 268 | Armed
# Processing Record 20 of 268 | The Cloverfield Paradox
# Processing Record 21 of 268 | Peter Rabbit
# Processing Record 22 of 268 | Fifty Shades Freed
# Processing Record 23 of 268 | The 15:17 to Paris
# Processing Record 24 of 268 | La Boda de Valentina
# Processing Record 25 of 268 | Kri
# Processing Record 26 of 268 | Permission
# Processing Record 27 of 268 | Monster Family
# Processing Record 28 of 268 | Golden Exits
# Processing Record 29 of 268 | Black Panther
# Processing Record 30 of 268 | Early Man
# Processing Record 31 of 268 | Loveless
# Processing Record 32 of 268 | The Party
# Processing Record 33 of 268 | Nostalgia
# Processing Record 34 of 268 | Black '47
# Processing Record 35 of 268 | Samson
# Processing Record 36 of 268 | Game Night
# Processing Record 37 of 268 | Annihilation
# Processing Record 38 of 268 | Every Day
# Processing Record 39 of 268 | The Cured
# Processing Record 40 of 268 | The Lodgers
# Processing Record 41 of 268 | Red Sparrow
# Processing Record 42 of 268 | Death Wish
# Processing Record 43 of 268 | The Vanishing of Sidney Hall
# Processing Record 44 of 268 | Foxtrot
# Processing Record 45 of 268 | Pickings
# Processing Record 46 of 268 | A Wrinkle in Time
# Processing Record 47 of 268 | Gringo
# Processing Record 48 of 268 | Thoroughbreds
# Processing Record 49 of 268 | The Death of Stalin
# Processing Record 50 of 268 | The Leisure Seeker
# Processing Record 51 of 268 | The Strangers: Prey at Night
# Processing Record 52 of 268 | The Hurricane Heist
# Processing Record 53 of 268 | Tomb Raider
# Processing Record 54 of 268 | Love, Simon
# Processing Record 55 of 268 | I Can Only Imagine
# Processing Record 56 of 268 | 7 Days in Entebbe
# Processing Record 57 of 268 | Furlough
# Processing Record 58 of 268 | Josie
# Processing Record 59 of 268 | Flower
# Processing Record 60 of 268 | Pacific Rim: Uprising
# Processing Record 61 of 268 | Isle of Dogs
# Processing Record 62 of 268 | Sherlock Gnomes
# Processing Record 63 of 268 | Unsane
# Processing Record 64 of 268 | Paul, Apostle of Christ
# Processing Record 65 of 268 | Final Portrait
# Processing Record 66 of 268 | Midnight Sun
# Processing Record 67 of 268 | Followers
# Processing Record 68 of 268 | Ready Player One
# Processing Record 68 of 268 | Tyler Perry's Acrimony not found - skipping.
# Processing Record 69 of 268 | God's Not Dead: A Light in Darkness
# Processing Record 70 of 268 | Gemini
# Processing Record 71 of 268 | The Last Movie Star
# Processing Record 72 of 268 | Title
# Processing Record 73 of 268 | A Quiet Place
# Processing Record 74 of 268 | Blockers
# Processing Record 75 of 268 | You Were Never Really Here
# Processing Record 76 of 268 | Chappaquiddick
# Processing Record 77 of 268 | Pandas
# Processing Record 78 of 268 | Lean on Pete
# Processing Record 79 of 268 | The Miracle Season
# Processing Record 80 of 268 | Beirut
# Processing Record 81 of 268 | Rampage
# Processing Record 82 of 268 | Truth or Dare
# Processing Record 83 of 268 | The Rider
# Processing Record 84 of 268 | Sgt. Stubby: An American Hero
# Processing Record 85 of 268 | I Feel Pretty
# Processing Record 86 of 268 | Super Troopers 2
# Processing Record 87 of 268 | Traffik
# Processing Record 88 of 268 | The House of Tomorrow
# Processing Record 89 of 268 | Liz and the Blue Bird
# Processing Record 90 of 268 | Avengers: Infinity War
# Processing Record 91 of 268 | Disobedience
# Processing Record 92 of 268 | Backstabbing for Beginners
# Processing Record 92 of 268 | Kings not found - skipping.
# Processing Record 93 of 268 | Overboard
# Processing Record 94 of 268 | Tully
# Processing Record 95 of 268 | Bad Samaritan
# Processing Record 96 of 268 | The Cleanse
# Processing Record 97 of 268 | The Guardians
# Processing Record 98 of 268 | Life of the Party
# Processing Record 99 of 268 | Breaking In
# Processing Record 100 of 268 | The Seagull
# Processing Record 101 of 268 | Terminal
# Processing Record 101 of 268 | Revenge not found - skipping.
# Processing Record 102 of 268 | Deadpool 2
# Processing Record 103 of 268 | Book Club
# Processing Record 104 of 268 | First Reformed
# Processing Record 105 of 268 | Pope Francis: A Man of His Word
# Processing Record 106 of 268 | Show Dogs
# Processing Record 107 of 268 | Solo: A Star Wars Story
# Processing Record 108 of 268 | How to Talk to Girls at Parties
# Processing Record 109 of 268 | In Darkness
# Processing Record 110 of 268 | The Misandrists
# Processing Record 111 of 268 | Future World
# Processing Record 112 of 268 | Action Point
# Processing Record 113 of 268 | Adrift
# Processing Record 114 of 268 | Upgrade
# Processing Record 115 of 268 | American Animals
# Processing Record 116 of 268 | Social Animals
# Processing Record 116 of 268 | Ocean's 8 not found - skipping.
# Processing Record 117 of 268 | Won't You Be My Neighbor?
# Processing Record 118 of 268 | Hereditary
# Processing Record 119 of 268 | Hotel Artemis
# Processing Record 120 of 268 | Superfly
# Processing Record 121 of 268 | Incredibles 2
# Processing Record 122 of 268 | Tag
# Processing Record 123 of 268 | On Chesil Beach
# Processing Record 124 of 268 | Gotti
# Processing Record 125 of 268 | Jurassic World: Fallen Kingdom
# Processing Record 126 of 268 | Boundaries
# Processing Record 127 of 268 | Damsel
# Processing Record 128 of 268 | The Domestics
# Processing Record 129 of 268 | Sicario: Day of the Soldado
# Processing Record 130 of 268 | Leave No Trace
# Processing Record 131 of 268 | Uncle Drew
# Processing Record 132 of 268 | Woman Walks Ahead
# Processing Record 133 of 268 | Title
# Processing Record 134 of 268 | The First Purge
# Processing Record 135 of 268 | Ant-Man and the Wasp
# Processing Record 136 of 268 | Sorry to Bother You
# Processing Record 136 of 268 | Whitney not found - skipping.
# Processing Record 137 of 268 | Hotel Transylvania 3: Summer Vacation
# Processing Record 138 of 268 | Skyscraper
# Processing Record 139 of 268 | Eighth Grade
# Processing Record 140 of 268 | Don't Worry, He Won't Get Far on Foot
# Processing Record 141 of 268 | Shock and Awe
# Processing Record 142 of 268 | Mamma Mia! Here We Go Again
# Processing Record 143 of 268 | The Equalizer 2
# Processing Record 144 of 268 | Blindspotting
# Processing Record 145 of 268 | Unfriended: Dark Web
# Processing Record 146 of 268 | Bleach
# Processing Record 146 of 268 | Gauguin  Voyage de Tahiti not found - skipping.
# Processing Record 146 of 268 | Mission: Impossible  Fallout not found - skipping.
# Processing Record 147 of 268 | Teen Titans Go! To the Movies
# Processing Record 148 of 268 | Detective Dee: The Four Heavenly Kings
# Processing Record 149 of 268 | Hot Summer Nights
# Processing Record 150 of 268 | Puzzle
# Processing Record 151 of 268 | Christopher Robin
# Processing Record 152 of 268 | The Darkest Minds
# Processing Record 153 of 268 | The Spy Who Dumped Me
# Processing Record 154 of 268 | The Miseducation of Cameron Post
# Processing Record 155 of 268 | Never Goin' Back
# Processing Record 156 of 268 | Dog Days
# Processing Record 157 of 268 | The Meg
# Processing Record 158 of 268 | BlacKkKlansman
# Processing Record 159 of 268 | Slender Man
# Processing Record 160 of 268 | A Prayer Before Dawn
# Processing Record 161 of 268 | Crazy Rich Asians
# Processing Record 162 of 268 | Alpha
# Processing Record 163 of 268 | Mile 22
# Processing Record 164 of 268 | The Wife
# Processing Record 165 of 268 | Billionaire Boys Club
# Processing Record 166 of 268 | Juliet, Naked
# Processing Record 167 of 268 | Down a Dark Hall
# Processing Record 168 of 268 | The Happytime Murders
# Processing Record 169 of 268 | Searching
# Processing Record 170 of 268 | Papillon
# Processing Record 171 of 268 | A.X.L.
# Processing Record 172 of 268 | Operation Finale
# Processing Record 173 of 268 | Kin
# Processing Record 174 of 268 | The Little Stranger
# Processing Record 175 of 268 | Destination Wedding
# Processing Record 176 of 268 | The Nun
# Processing Record 177 of 268 | Peppermint
# Processing Record 178 of 268 | The Predator
# Processing Record 179 of 268 | White Boy Rick
# Processing Record 180 of 268 | A Simple Favor
# Processing Record 181 of 268 | The Children Act
# Processing Record 182 of 268 | Lizzie
# Processing Record 183 of 268 | Unbroken: Path to Redemption
# Processing Record 184 of 268 | The House with a Clock in Its Walls
# Processing Record 185 of 268 | Life Itself
# Processing Record 186 of 268 | The Sisters Brothers
# Processing Record 187 of 268 | Assassination Nation
# Processing Record 188 of 268 | Colette
# Processing Record 189 of 268 | Fahrenheit 11/9
# Processing Record 190 of 268 | My Son
# Processing Record 191 of 268 | Love, Gilda
# Processing Record 192 of 268 | My Hero Academia: Two Heroes
# Processing Record 193 of 268 | Smallfoot
# Processing Record 194 of 268 | Night School
# Processing Record 195 of 268 | The Old Man & the Gun
# Processing Record 196 of 268 | Hell Fest
# Processing Record 197 of 268 | Title
# Processing Record 198 of 268 | Power of the Air
# Processing Record 199 of 268 | Venom
# Processing Record 200 of 268 | A Star Is Born
# Processing Record 201 of 268 | The Hate U Give
# Processing Record 202 of 268 | The Happy Prince
# Processing Record 203 of 268 | First Man
# Processing Record 204 of 268 | Bad Times at the El Royale
# Processing Record 205 of 268 | Goosebumps 2: Haunted Halloween
# Processing Record 206 of 268 | Beautiful Boy
# Processing Record 207 of 268 | The Oath
# Processing Record 208 of 268 | Gosnell: The Trial of America's Biggest Serial Killer
# Processing Record 209 of 268 | Halloween
# Processing Record 210 of 268 | Can You Ever Forgive Me?
# Processing Record 211 of 268 | Mid90s
# Processing Record 212 of 268 | Wildlife
# Processing Record 213 of 268 | What They Had
# Processing Record 214 of 268 | Hunter Killer
# Processing Record 215 of 268 | Johnny English Strikes Again
# Processing Record 216 of 268 | Suspiria
# Processing Record 217 of 268 | Indivisible
# Processing Record 218 of 268 | Bullitt County
# Processing Record 219 of 268 | Bohemian Rhapsody
# Processing Record 220 of 268 | The Nutcracker and the Four Realms
# Processing Record 221 of 268 | Nobody's Fool
# Processing Record 222 of 268 | Boy Erased
# Processing Record 223 of 268 | A Private War
# Processing Record 224 of 268 | Bodied
# Processing Record 225 of 268 | The Front Runner
# Processing Record 226 of 268 | The Grinch
# Processing Record 227 of 268 | The Girl in the Spider's Web
# Processing Record 228 of 268 | Overlord
# Processing Record 229 of 268 | Lazer Team 2
# Processing Record 230 of 268 | Conundrum: Secrets Among Friends
# Processing Record 231 of 268 | Fantastic Beasts: The Crimes of Grindelwald
# Processing Record 232 of 268 | Widows
# Processing Record 233 of 268 | Instant Family
# Processing Record 234 of 268 | Ralph Breaks the Internet
# Processing Record 235 of 268 | Creed II
# Processing Record 236 of 268 | Robin Hood
# Processing Record 237 of 268 | Green Book
# Processing Record 238 of 268 | Roma
# Processing Record 239 of 268 | The Favourite
# Processing Record 240 of 268 | Shoplifters
# Processing Record 241 of 268 | Mowgli: Legend of the Jungle
# Processing Record 242 of 268 | The Possession of Hannah Grace
# Processing Record 243 of 268 | Anna and the Apocalypse
# Processing Record 244 of 268 | Capernaum
# Processing Record 245 of 268 | Mary Queen of Scots
# Processing Record 246 of 268 | Ben Is Back
# Processing Record 247 of 268 | Spider-Man: Into the Spider-Verse
# Processing Record 248 of 268 | Mortal Engines
# Processing Record 249 of 268 | The Mule
# Processing Record 250 of 268 | If Beale Street Could Talk
# Processing Record 251 of 268 | Mary Poppins Returns
# Processing Record 252 of 268 | Aquaman
# Processing Record 253 of 268 | Bumblebee
# Processing Record 254 of 268 | Welcome to Marwen
# Processing Record 255 of 268 | Second Act
# Processing Record 256 of 268 | Cold War
# Processing Record 257 of 268 | Holmes & Watson
# Processing Record 258 of 268 | Vice
# Processing Record 259 of 268 | On the Basis of Sex
# Processing Record 260 of 268 | Destroyer
# Processing Record 261 of 268 | Black Mirror: Bandersnatch
# 97.4% of movies found

# %%
df = pd.DataFrame({'Title': titles, 'Metascore': metascore, 'Ratings': ratings,'Runtime': runtime,'Released': released, 'Genre': genre})
df.to_csv("films.csv", encoding="utf-8", index=False)
df.count()
# Out:
# Title        264
# Metascore    264
# Ratings      264
# Runtime      264
# Released     264
# Genre        264
# dtype: int64

# %%
df.head()
# Out:
#               Title Metascore Ratings  Runtime     Released  \
# 0  The Strange Ones        57       R   81 min  05 Jan 2018
# 1          Stratton        26       R   95 min  05 Jan 2018
# 2     Sweet Country        87       R  113 min  06 Apr 2018
# 3      The Commuter        56   PG-13  105 min  12 Jan 2018
# 4        Proud Mary        35       R   89 min  12 Jan 2018
#
#                                                Genre
# 0                                    Drama, Thriller
# 1                                   Action, Thriller
# 2  Adventure, Crime, Drama, History, Thriller, We...
# 3                          Action, Mystery, Thriller
# 4                     Action, Crime, Drama, Thriller
