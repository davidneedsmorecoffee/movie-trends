# %%
import omdb
import os
import pandas as pd
import numpy as np
import requests

omdb.set_default('apikey', "82e97a07")

# [DL] I ended up pulling the movies into one single CSV file
# one column has the titles, one column has the years

# L99_03 = ['1999','2000','2001','2002','2003'] #Adam
# L04_08 = ['2004','2005','2006','2007','2008'] #David
# L09_13 = ['2009','2010','2011','2012','2013'] #Neil
# L14_18 = ['2014','2015','2016','2017','2018'] #Robin
#df = pd.read_excel('movies_1999_2019.xlsx',sheet_name =L04_08,encoding='latin-1',header = None)

# %%
df = pd.read_csv("movies_1999_2019_singletable_ut8.csv")
#df = pd.read_csv("../resources/movies_metadata.csv")
df.head(10)
# Out:
#                                   Title  Year
# 0            10 Things I Hate About You  1999
# 1                      The 13th Warrior  1999
# 2                        200 Cigarettes  1999
# 3                         The 4th Floor  1999
# 4                                   8mm  1999
# 5  The Adventures of Elmo in Grouchland  1999
# 6                       American Beauty  1999
# 7                        American Movie  1999
# 8                          American Pie  1999
# 9                          Analyze This  1999

# %%
# films_04 = df.loc[df['Year']==2004]
# films_05 = df.loc[df['Year']==2005]
# films_06 = df.loc[df['Year']==2006]
# films_07 = df.loc[df['Year']==2007]
# films_08 = df.loc[df['Year']==2008]

# %%
films_2004to2008 = df.loc[(df['Year']==2004) | (df['Year']==2005) | (df['Year']==2006) | (df['Year']==2007) | (df['Year']==2008)]
len(films_2004to2008)

# [Dl] pulling just the first 50 movies for a quick test
films_2004to2008_test = films_2004to2008.head(50)

# %%
# df[0] will be the first year in the list, [1] the second, etc.
# Module for reading CSV files

# [DL] this pulls the 'Title' for the API call later on
films_2004to2008_test['Title']
# Out:
# 1113                              13 Going on 30
# 1114                              50 First Dates
# 1115                            After the Sunset
# 1116                           Against the Ropes
# 1117      Agent Cody Banks 2: Destination London
# 1118                                   The Alamo
# 1119                                   Alexander
# 1120                                       Alfie
# 1121                          Alien vs. Predator
# 1122                            Along Came Polly
# 1123                    America's Heart and Soul
# 1124    Anacondas: The Hunt for the Blood Orchid
# 1125       Anchorman: The Legend of Ron Burgundy
# 1126                             Around the Bend
# 1127                 Around the World in 80 Days
# 1128          The Assassination of Richard Nixon
# 1129                                 The Aviator
# 1130              Barbershop 2: Back in Business
# 1131                               Before Sunset
# 1132                                 Being Julia
# 1133                       Benji: Off the Leash!
# 1134                 The Best Thief in the World
# 1135                              Beyond the Sea
# 1136                              The Big Bounce
# 1137                                       Birth
# 1138                              Blade: Trinity
# 1139                                 Black Cloud
# 1140                          The Blue Butterfly
# 1141               Bobby Jones: Stroke of Genius
# 1142                                Book of Love
# 1143                          Born into Brothels
# 1144                        The Bourne Supremacy
# 1145                      Breakin' All the Rules
# 1146           Bridget Jones: The Edge of Reason
# 1147                          Brother to Brother
# 1148                        The Butterfly Effect
# 1149                              Catch That Kid
# 1150                                    Catwoman
# 1151                                    Cellular
# 1152                               Celsius 41.11
# 1153                             Chasing Liberty
# 1154                   Christmas with the Kranks
# 1155                   The Chronicles of Riddick
# 1156                          A Cinderella Story
# 1157                                The Clearing
# 1158                 Clifford's Really Big Movie
# 1159                                      Closer
# 1160                           Cloud Cuckoo Land
# 1161                                  Club Dread
# 1162                                  Collateral
# Name: Title, dtype: object

# %%
titles = []
metascore = []
imdb_rating = []
imdb_votes = []
rated = []
runtime = []
released = []
genre = []
box_office = []
year = []

imdb_source = []
imdb_score = []

rotten_source = [] # [DL] not used yet. depends on if we want to include the rotten tomatoe info
rotten_score = []

metacrit_source = [] # [DL] not used yet. depends on if we want to include the metacritic info
metacrit_score = []

notfound = 0
found = 0
total = len(df)
j = 0

# %%
for film in films_2004to2008_test['Title']:
    try:
        response = omdb.get(title={film}) 
        titles.append(response["title"])
    except:
        titles.append('null')
    try:
        box_office.append(response["box_office"])
    except:
        box_office.append('null')
    try:
        metascore.append(response["metascore"])
    except:
        metascore.append('null')
    try:
        imdb_rating.append(response["imdb_rating"])
    except:
        imdb_rating.append('null')
    try:
        imdb_votes.append(response["imdb_votes"])
    except:
        imdb_votes.append('null')
    try:
        rated.append(response["rated"])
    except:
        rated.append('null')
    try:
        genre.append(response["genre"])
    except:
        genre.append('null')
    try:
        runtime.append(response["runtime"])
    except:
        runtime.append('null')
    try:
        released.append(response["released"])
    except: 
        released.append('null')
    try:
        year.append(response["year"])
    except:
        year.append('null')


        #imdb_source.append(response['ratings'][0]['source']) #IMDB source 
        #imdb_score.append(response['ratings'][0]['value']) #IMDB score
        
         

        #rotten_source.append(response['ratings'][1]['source']) #rotten tomatoes source
        #rotten_score.append(response['ratings'][1]['value']) #rotten tomatoes score

        #metacrit_source.append(response['ratings'][2]['source']) #metacritic source
        #metacrit_source.append(response['ratings'][2]['value']) #metacritic score

        #j += 1
        #found += 1
        #print(f"Processing Record {j} of {total} | {film}")
#     except:
#         print(f"Processing Record {j} of {total} | {film} not found - skipping.")
#         notfound += 1
        
#pct_movie_found = round(found/(notfound+found)*100,1)       
#print(f"{pct_movie_found}% of movies found")

# Coverting to a dataframe 


df = pd.DataFrame({'Title': titles, 'Metascore': metascore, 'Rated': rated,'Runtime': runtime,'Released': released, 'Year': year, 'Genre': genre,'Box Office': box_office,
                  'imdb_rating': imdb_rating, 'imdb_votes': imdb_votes})
#df
#df = pd.DataFrame({'Title': titles, 'Metascore': metascore, 'Rated': rated,'Runtime': runtime,'Released': released, 'Year': year, 'Genre': genre,'Box Office': box_office,
                  #'imdb_rating': imdb_rating, 'imdb_votes': imdb_votes, 'imdb_source':imdb_source, 'imdb_score':imdb_score, 'rotten_source': rotten_source, 'rotten_score': rotten_score})
#df.to_csv("films.csv", encoding="utf-8", index=False)

# %%
df
# Out:
#                                                 Title Metascore      Rated  \
# 0                                      13 Going on 30        57      PG-13
# 1                                      50 First Dates        48      PG-13
# 2                                    After the Sunset        38      PG-13
# 3                                   Against the Ropes        36      PG-13
# 4              Agent Cody Banks 2: Destination London        32         PG
# 5                                           The Alamo        47      PG-13
# 6                                           Alexander        39          R
# 7                                               Alfie        49          R
# 8                                  Alien vs. Predator        29      PG-13
# 9                                    Along Came Polly        44      PG-13
# 10                                               null      null       null
# 11           Anacondas: The Hunt for the Blood Orchid        40      PG-13
# 12              Anchorman: The Legend of Ron Burgundy        63      PG-13
# 13                                    Around the Bend        46          R
# 14                        Around the World in 80 Days        49         PG
# 15                 The Assassination of Richard Nixon        63          R
# 16                                        The Aviator        77      PG-13
# 17                     Barbershop 2: Back in Business        59      PG-13
# 18                                      Before Sunset        90          R
# 19                                        Being Julia        65          R
# 20                              Benji: Off the Leash!        49         PG
# 21                        The Best Thief in the World       N/A          R
# 22                                     Beyond the Sea        46      PG-13
# 23                                     The Big Bounce        42      PG-13
# 24                                              Birth        50          R
# 25                                     Blade: Trinity        38          R
# 26                                        Black Cloud       N/A      PG-13
# 27                                 The Blue Butterfly       N/A         PG
# 28                      Bobby Jones: Stroke of Genius        45         PG
# 29                                       Book of Love       N/A          R
# 30      Born Into Brothels: Calcutta's Red Light Kids        78          R
# 31                               The Bourne Supremacy        73      PG-13
# 32                             Breakin' All the Rules        46      PG-13
# 33                  Bridget Jones: The Edge of Reason        44          R
# 34                                 Brother to Brother        57  Not Rated
# 35                               The Butterfly Effect        30          R
# 36                                     Catch That Kid        33         PG
# 37                                           Catwoman        27      PG-13
# 38                                           Cellular        60      PG-13
# 39  Celsius 41.11: The Temperature at Which the Br...        42          R
# 40                                    Chasing Liberty        46      PG-13
# 41                          Christmas with the Kranks        22         PG
# 42                          The Chronicles of Riddick        38          R
# 43                                 A Cinderella Story        25         PG
# 44                                       The Clearing        60          R
# 45                        Clifford's Really Big Movie        49          G
# 46                                             Closer        65          R
# 47                                  Cloud Cuckoo Land       N/A        N/A
# 48                                         Club Dread        45          R
# 49                                         Collateral        71          R
#
#     Runtime     Released  Year  \
# 0    98 min  23 Apr 2004  2004
# 1    99 min  13 Feb 2004  2004
# 2    97 min  12 Nov 2004  2004
# 3   111 min  20 Feb 2004  2004
# 4   100 min  12 Mar 2004  2004
# 5   137 min  09 Apr 2004  2004
# 6   175 min  24 Nov 2004  2004
# 7   103 min  05 Nov 2004  2004
# 8   101 min  13 Aug 2004  2004
# 9    90 min  16 Jan 2004  2004
# 10     null         null  null
# 11   97 min  27 Aug 2004  2004
# 12   94 min  09 Jul 2004  2004
# 13   85 min  20 Jan 2005  2004
# 14  120 min  16 Jun 2004  2004
# 15   95 min  22 Oct 2004  2004
# 16  170 min  25 Dec 2004  2004
# 17  106 min  06 Feb 2004  2004
# 18   80 min  30 Jul 2004  2004
# 19  104 min  18 Feb 2005  2004
# 20   97 min  20 Aug 2004  2004
# 21   93 min  16 Jan 2004  2004
# 22  118 min  29 Dec 2004  2004
# 23   88 min  30 Jan 2004  2004
# 24  100 min  29 Oct 2004  2004
# 25  113 min  08 Dec 2004  2004
# 26   97 min  30 Apr 2004  2004
# 27   97 min  26 Aug 2004  2004
# 28  120 min  30 Apr 2004  2004
# 29   83 min  18 Jan 2004  2004
# 30   85 min  11 Mar 2005  2004
# 31  108 min  23 Jul 2004  2004
# 32   85 min  14 May 2004  2004
# 33  108 min  19 Nov 2004  2004
# 34   94 min  17 Jan 2004  2004
# 35  113 min  23 Jan 2004  2004
# 36   91 min  06 Feb 2004  2004
# 37  104 min  23 Jul 2004  2004
# 38   94 min  10 Sep 2004  2004
# 39   72 min  22 Oct 2004  2004
# 40  111 min  09 Jan 2004  2004
# 41   99 min  24 Nov 2004  2004
# 42  119 min  11 Jun 2004  2004
# 43   95 min  16 Jul 2004  2004
# 44   95 min  16 Jul 2004  2004
# 45   74 min  23 Apr 2004  2004
# 46  104 min  03 Dec 2004  2004
# 47   92 min  15 Aug 2012  2012
# 48  104 min  27 Feb 2004  2004
# 49  120 min  06 Aug 2004  2004
#
#                                                 Genre    Box Office  \
# 0                            Comedy, Fantasy, Romance   $54,600,000
# 1                              Comedy, Drama, Romance  $120,776,832
# 2                        Action, Comedy, Crime, Drama   $28,300,000
# 3                    Biography, Drama, Romance, Sport    $5,696,752
# 4   Action, Adventure, Comedy, Family, Romance, Sc...   $23,222,861
# 5                        Drama, History, War, Western           N/A
# 6     Action, Biography, Drama, History, Romance, War   $34,264,081
# 7                              Comedy, Drama, Romance   $13,351,235
# 8         Action, Adventure, Horror, Sci-Fi, Thriller   $80,218,314
# 9                                     Comedy, Romance   $87,856,565
# 10                                               null          null
# 11                Action, Adventure, Horror, Thriller   $31,500,000
# 12                                             Comedy   $84,136,909
# 13                                              Drama      $117,093
# 14         Action, Adventure, Comedy, Family, Western           N/A
# 15         Biography, Crime, Drama, History, Thriller      $578,554
# 16                                   Biography, Drama  $102,563,679
# 17                                      Comedy, Drama   $64,955,956
# 18                                     Drama, Romance    $5,600,000
# 19                             Comedy, Drama, Romance    $7,652,647
# 20                                      Drama, Family    $3,700,000
# 21                                      Comedy, Drama           N/A
# 22                   Biography, Drama, Music, Musical    $6,144,806
# 23                                      Comedy, Crime    $6,331,346
# 24                  Drama, Fantasy, Mystery, Thriller    $5,005,883
# 25        Action, Adventure, Horror, Sci-Fi, Thriller   $52,400,000
# 26                                              Drama           N/A
# 27                                   Drama, Adventure           N/A
# 28                   Biography, Drama, Romance, Sport    $2,536,460
# 29                                      Comedy, Drama           N/A
# 30                                        Documentary    $3,370,574
# 31                          Action, Mystery, Thriller  $176,049,130
# 32                                    Comedy, Romance   $11,827,301
# 33                             Comedy, Drama, Romance   $40,203,020
# 34                                              Drama           N/A
# 35                            Drama, Sci-Fi, Thriller   $57,200,000
# 36          Adventure, Comedy, Crime, Family, Mystery   $16,532,227
# 37                             Action, Crime, Fantasy   $40,200,000
# 38                            Action, Crime, Thriller   $32,003,620
# 39                                   Documentary, War           N/A
# 40                                    Comedy, Romance           N/A
# 41                                     Comedy, Family   $73,701,902
# 42                Action, Adventure, Sci-Fi, Thriller   $56,800,000
# 43                            Comedy, Family, Romance   $51,100,000
# 44                           Drama, Mystery, Thriller    $5,572,013
# 45               Animation, Adventure, Comedy, Family    $2,782,548
# 46                                     Drama, Romance   $33,987,757
# 47                                              Drama           N/A
# 48                  Comedy, Horror, Mystery, Thriller    $4,559,739
# 49                             Crime, Drama, Thriller  $100,003,492
#
#    imdb_rating imdb_votes
# 0          6.1    152,200
# 1          6.8    307,481
# 2          6.3     42,616
# 3          5.3      6,384
# 4          4.5     13,203
# 5          6.0     18,759
# 6          5.6    155,529
# 7          6.2     48,352
# 8          5.6    175,415
# 9          5.9    119,453
# 10        null       null
# 11         4.6     26,613
# 12         7.2    311,081
# 13         6.4      4,056
# 14         5.9     79,633
# 15         7.0     24,686
# 16         7.5    311,215
# 17         5.7     13,542
# 18         8.0    211,375
# 19         7.0     11,612
# 20         4.7        489
# 21         4.9        456
# 22         6.7     14,079
# 23         4.9     17,147
# 24         6.1     32,911
# 25         5.9    157,611
# 26         6.1        464
# 27         6.3      1,408
# 28         6.7      3,574
# 29         5.4      1,553
# 30         7.3     14,809
# 31         7.7    410,791
# 32         5.7      5,660
# 33         6.0     97,616
# 34         7.0      1,023
# 35         7.6    425,529
# 36         5.2      9,131
# 37         3.3    103,518
# 38         6.5     88,721
# 39         4.4      1,367
# 40         6.1     34,596
# 41         5.3     37,139
# 42         6.7    205,541
# 43         5.9     75,820
# 44         5.9     12,786
# 45         5.3        675
# 46         7.2    192,169
# 47         7.3         24
# 48         5.7     27,021
# 49         7.5    337,991

# %%
print(len(titles))
print(len(metascore))
print(len(runtime))
print(len(released))
print(len(year))
print(len(genre))
print(len(box_office))
print(len(imdb_rating))
print(len(imdb_votes))
# Out:
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50

# %%
#lst1 <- lapply(response, function(x) do.call(c,lapply(x, function(y) {y[is.null(y)] <- NA;y}))) 

#df = pd.DataFrame({'Title': titles, 'Metascore': metascore, 'Rated': rated,'Runtime': runtime,'Released': released, 'Year': year, 'Genre': genre,'Box Office': box_office,
                  #'imdb_rating': imdb_rating, 'imdb_votes': imdb_votes})
#df.to_csv("films.csv", encoding="utf-8", index=False)
