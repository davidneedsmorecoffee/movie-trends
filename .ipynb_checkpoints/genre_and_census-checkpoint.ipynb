# %% [markdown]
# # Genre Section

# %%
# immport modules
import os
import pandas as pd
import numpy as np
import requests
import datetime
import matplotlib.pyplot as plt
from scipy.stats import linregress
# %matplotlib inline

# %%
# read file
df = pd.read_csv('All_Movies_Working.csv')   #All_Movies_Working.csv
genre_df = df
genre_df.head()
# Out:
#                    Title  Metascore  Rated  Runtime     Released  \
# 0                Beowulf       59.0  PG-13  115 min  16 Nov 2007
# 1  But I'm a Cheerleader       39.0      R   85 min  11 Aug 2000
# 2               Flawless       57.0  PG-13  108 min  28 Mar 2008
# 3                 Gloria       83.0      R  110 min  09 May 2013
# 4                   Life       54.0      R  104 min  24 Mar 2017
#
#                                    Genre  Box Office  imdb_rating imdb_votes  \
# 0  Animation, Action, Adventure, Fantasy  82200000.0          6.2    155,920
# 1                 Comedy, Drama, Romance    175182.0          6.6     23,614
# 2                 Crime, Drama, Thriller   1146525.0          6.8     21,901
# 3                 Comedy, Drama, Romance   1587655.0          6.8      7,804
# 4               Horror, Sci-Fi, Thriller  30180466.0          6.6    185,922
#
#                imdb_source  imdb_score    rotten_source  rotten_score  \
# 0  Internet Movie Database         6.2  Rotten Tomatoes           7.1
# 1  Internet Movie Database         6.6  Rotten Tomatoes           3.9
# 2  Internet Movie Database         6.8  Rotten Tomatoes           5.5
# 3  Internet Movie Database         6.8  Rotten Tomatoes           9.9
# 4  Internet Movie Database         6.6  Rotten Tomatoes           6.8
#
#   metacrit_source  metacrit_score  release_month  release_year
# 0      Metacritic             5.9             11          2007
# 1      Metacritic             3.9              8          2000
# 2      Metacritic             5.7              3          2008
# 3      Metacritic             8.3              5          2013
# 4      Metacritic             5.4              3          2017

# %%
# create discrete genre columns
comedy = genre_df["Genre"].str.contains("Comedy", case=True, regex=True)
action = genre_df["Genre"].str.contains("Action", case=True, regex=True)
drama = genre_df["Genre"].str.contains("Drama", case=True, regex=True)
romance = genre_df["Genre"].str.contains("Romance", case=True, regex=True)
thriller = genre_df["Genre"].str.contains("Thriller", case=True, regex=True)
adventure = genre_df["Genre"].str.contains("Adventure", case=True, regex=True)
crime = genre_df["Genre"].str.contains("Crime", case=True, regex=True)
fantasy = genre_df["Genre"].str.contains("Fantasy", case=True, regex=True)
family = genre_df["Genre"].str.contains("Family", case=True, regex=True)
scifi = genre_df["Genre"].str.contains("Sci-Fi", case=True, regex=True)

# %%
# add columns to dataframe
genre_df["comedy"] = comedy
genre_df["action"] = action
genre_df["drama"] = drama
genre_df["romance"] = romance
genre_df["thriller"] = thriller
genre_df["adventure"] = adventure
genre_df["crime"] = crime
genre_df["fantasy"] = fantasy
genre_df["family"] = family
genre_df["scifi"] = scifi
genre_df["Box Office"] = genre_df["Box Office"] / 1000000
genre_df.head()
# Out:
#                    Title  Metascore  Rated  Runtime     Released  \
# 0                Beowulf       59.0  PG-13  115 min  16 Nov 2007
# 1  But I'm a Cheerleader       39.0      R   85 min  11 Aug 2000
# 2               Flawless       57.0  PG-13  108 min  28 Mar 2008
# 3                 Gloria       83.0      R  110 min  09 May 2013
# 4                   Life       54.0      R  104 min  24 Mar 2017
#
#                                    Genre  Box Office  imdb_rating imdb_votes  \
# 0  Animation, Action, Adventure, Fantasy   82.200000          6.2    155,920
# 1                 Comedy, Drama, Romance    0.175182          6.6     23,614
# 2                 Crime, Drama, Thriller    1.146525          6.8     21,901
# 3                 Comedy, Drama, Romance    1.587655          6.8      7,804
# 4               Horror, Sci-Fi, Thriller   30.180466          6.6    185,922
#
#                imdb_source  ...  comedy action  drama romance  thriller  \
# 0  Internet Movie Database  ...   False   True  False   False     False
# 1  Internet Movie Database  ...    True  False   True    True     False
# 2  Internet Movie Database  ...   False  False   True   False      True
# 3  Internet Movie Database  ...    True  False   True    True     False
# 4  Internet Movie Database  ...   False  False  False   False      True
#
#    adventure  crime  fantasy  family  scifi
# 0       True  False     True   False  False
# 1      False  False    False   False  False
# 2      False   True    False   False  False
# 3      False  False    False   False  False
# 4      False  False    False   False   True
#
# [5 rows x 27 columns]

# %%
# setup loc tables filtered by each genre
comedy_loc = genre_df.loc[genre_df["comedy"] == True]
action_loc = genre_df.loc[genre_df["action"] == True]
drama_loc = genre_df.loc[genre_df["drama"] == True]
romance_loc = genre_df.loc[genre_df["romance"] == True]
thriller_loc = genre_df.loc[genre_df["thriller"] == True]
adventure_loc = genre_df.loc[genre_df["adventure"] == True]
crime_loc = genre_df.loc[genre_df["crime"] == True]
fantasy_loc = genre_df.loc[genre_df["fantasy"] == True]
family_loc = genre_df.loc[genre_df["family"] == True]
scifi_loc = genre_df.loc[genre_df["scifi"] == True]

# test one
comedy_loc
# Out:
#                                Title  Metascore  Rated  Runtime     Released  \
# 1              But I'm a Cheerleader       39.0      R   85 min  11 Aug 2000
# 3                             Gloria       83.0      R  110 min  09 May 2013
# 5                     102 Dalmatians       35.0      G  100 min  22 Nov 2000
# 8                      Almost Famous       90.0      R  122 min  22 Sep 2000
# 10                        Bamboozled       50.0      R  135 min  20 Oct 2000
# 11                         Beautiful       23.0  PG-13  112 min  29 Sep 2000
# 13                      Best in Show       78.0  PG-13   90 min  20 Oct 2000
# 14                 Big Momma's House       33.0  PG-13   99 min  02 Jun 2000
# 16                       Bring It On       52.0  PG-13   98 min  25 Aug 2000
# 17                  Charlie's Angels       52.0  PG-13   98 min  03 Nov 2000
# 19                          The Crew       37.0  PG-13   88 min  25 Aug 2000
# 22                 Dr. T & the Women       64.0      R  122 min  13 Oct 2000
# 23             Dude, Where's My Car?       30.0  PG-13   83 min  15 Dec 2000
# 24                             Duets       40.0      R  112 min  15 Sep 2000
# 26          The Emperor's New Groove       70.0      G   78 min  15 Dec 2000
# 27              An Everlasting Piece       56.0      R  103 min  23 Mar 2001
# 35    How the Grinch Stole Christmas       46.0     PG  104 min  17 Nov 2000
# 36                    The Ladies Man       22.0      R   84 min  13 Oct 2000
# 38                      Little Nicky       38.0  PG-13   90 min  10 Nov 2000
# 39                The Little Vampire       45.0     PG   95 min  27 Oct 2000
# 40                     Lucky Numbers       31.0      R  105 min  27 Oct 2000
# 41                Me, Myself & Irene       49.0      R  116 min  23 Jun 2000
# 42                  Meet the Parents       73.0  PG-13  108 min  06 Oct 2000
# 44    Nutty Professor II: The Klumps       38.0  PG-13  106 min  28 Jul 2000
# 45        O Brother, Where Art Thou?       69.0  PG-13  107 min  02 Feb 2001
# 46      The Original Kings of Comedy       76.0      R  115 min  18 Aug 2000
# 53                  The Replacements       30.0  PG-13  118 min  11 Aug 2000
# 58                            Snatch       55.0      R  102 min  19 Jan 2001
# 60                  The Tao of Steve       70.0      R   87 min  01 Sep 2000
# 70                   What Women Want       47.0  PG-13  127 min  15 Dec 2000
# ...                              ...        ...    ...      ...          ...
# 2685                 The Emoji Movie       12.0     PG   86 min  28 Jul 2017
# 2688                    Brigsby Bear       68.0  PG-13   97 min  21 Sep 2017
# 2696  The Nut Job 2: Nutty by Nature       36.0     PG   91 min  11 Aug 2017
# 2698                Ingrid Goes West       71.0      R   98 min  25 Aug 2017
# 2700          The Hitman's Bodyguard       47.0      R  118 min  18 Aug 2017
# 2701                     Logan Lucky       78.0  PG-13  118 min  18 Aug 2017
# 2707                      Home Again       41.0  PG-13   97 min  08 Sep 2017
# 2710                   Brad's Status       71.0      R  102 min  15 Sep 2017
# 2711     Kingsman: The Golden Circle       44.0      R  141 min  22 Sep 2017
# 2712          The Lego Ninjago Movie       55.0     PG  101 min  22 Sep 2017
# 2714             Battle of the Sexes       73.0  PG-13  121 min  29 Sep 2017
# 2717                   American Made       65.0      R  115 min  29 Sep 2017
# 2720       My Little Pony: The Movie       39.0     PG   99 min  06 Oct 2017
# 2728        Boo 2! A Madea Halloween       17.0  PG-13  101 min  20 Oct 2017
# 2735                  Thor: Ragnarok       74.0  PG-13  130 min  03 Nov 2017
# 2736            A Bad Moms Christmas       42.0      R  104 min  01 Nov 2017
# 2737                Last Flag Flying       65.0      R  125 min  03 Nov 2017
# 2738                       Lady Bird       94.0      R   94 min  01 Dec 2017
# 2740                  Daddy's Home 2       30.0  PG-13  100 min  10 Nov 2017
# 2744                        The Star       42.0     PG   86 min  17 Nov 2017
# 2749  The Man Who Invented Christmas       60.0     PG  104 min  22 Nov 2017
# 2751                        I, Tonya       77.0      R  120 min  19 Jan 2018
# 2753                       Ferdinand       58.0     PG  108 min  15 Dec 2017
# 2754  Jumanji: Welcome to the Jungle       58.0  PG-13  119 min  20 Dec 2017
# 2756                 Pitch Perfect 3       40.0  PG-13   93 min  22 Dec 2017
# 2758                  Father Figures       22.0      R  113 min  22 Dec 2017
# 2771                    Peter Rabbit       51.0     PG   95 min  09 Feb 2018
# 2776                      Game Night       66.0      R  100 min  23 Feb 2018
# 2787            Little Miss Sunshine       80.0      R  101 min  18 Aug 2006
# 2791                Charlie's Angels       52.0  PG-13   98 min  03 Nov 2000
#
#                                                   Genre  Box Office  \
# 1                                Comedy, Drama, Romance    0.175182
# 3                                Comedy, Drama, Romance    1.587655
# 5                             Adventure, Comedy, Family   65.406212
# 8                       Adventure, Comedy, Drama, Music   31.716715
# 10                                 Comedy, Drama, Music    1.883628
# 11                                        Drama, Comedy    2.834122
# 13                                               Comedy   16.574225
# 14                                Action, Comedy, Crime    0.492734
# 16                               Comedy, Romance, Sport   67.905760
# 17           Action, Adventure, Comedy, Crime, Thriller  124.420707
# 19                                        Crime, Comedy   12.485210
# 22                               Comedy, Drama, Romance   12.115208
# 23                              Comedy, Mystery, Sci-Fi   44.992961
# 24                        Comedy, Drama, Music, Romance    4.262782
# 26        Animation, Adventure, Comedy, Family, Fantasy   87.320505
# 27                                               Comedy    0.009128
# 35                              Comedy, Family, Fantasy  259.011600
# 36                                               Comedy   13.384928
# 38                                      Comedy, Fantasy   38.542597
# 39                   Adventure, Comedy, Family, Fantasy   13.432508
# 40                                        Comedy, Crime    9.534013
# 41                                               Comedy    0.560525
# 42                                      Comedy, Romance  164.454835
# 44                              Comedy, Romance, Sci-Fi  122.385345
# 45                      Adventure, Comedy, Crime, Music   45.150731
# 46                                  Comedy, Documentary   37.680981
# 53                                        Comedy, Sport   44.004460
# 58                                        Comedy, Crime   30.093107
# 60                               Comedy, Drama, Romance    2.586310
# 70                             Comedy, Fantasy, Romance  181.483882
# ...                                                 ...         ...
# 2685      Animation, Adventure, Comedy, Family, Fantasy   86.053485
# 2688                                      Comedy, Drama    0.529426
# 2696      Animation, Adventure, Comedy, Family, Fantasy   28.342490
# 2698                                      Comedy, Drama    3.016057
# 2700                           Action, Comedy, Thriller   75.020039
# 2701                               Comedy, Crime, Drama   27.696504
# 2707                             Comedy, Drama, Romance   26.353346
# 2710                               Comedy, Drama, Music    2.029594
# 2711                          Action, Adventure, Comedy   99.733121
# 2712       Animation, Action, Adventure, Comedy, Family   58.938889
# 2714                    Biography, Comedy, Drama, Sport   12.552907
# 2717                   Action, Biography, Comedy, Crime   51.071805
# 2720  Animation, Adventure, Comedy, Drama, Family, F...   21.732671
# 2728                              Comedy, Drama, Horror   46.649659
# 2735         Action, Adventure, Comedy, Fantasy, Sci-Fi  314.971245
# 2736                                             Comedy   72.080547
# 2737                                 Comedy, Drama, War    0.411864
# 2738                                      Comedy, Drama   48.285330
# 2740                                             Comedy  102.934995
# 2744      Animation, Adventure, Comedy, Family, Fantasy   40.448404
# 2749                           Biography, Comedy, Drama    5.652908
# 2751                    Biography, Comedy, Drama, Sport   28.950158
# 2753      Animation, Adventure, Comedy, Family, Fantasy   70.466891
# 2754                 Action, Adventure, Comedy, Fantasy  393.201353
# 2756                                      Comedy, Music  104.880310
# 2758                               Comedy, Drama, Sport   16.772934
# 2771      Animation, Adventure, Comedy, Family, Fantasy   84.060376
# 2776                     Action, Comedy, Crime, Mystery   33.537766
# 2787                                      Comedy, Drama   59.831476
# 2791         Action, Adventure, Comedy, Crime, Thriller  124.420707
#
#       imdb_rating imdb_votes              imdb_source  ...  comedy action  \
# 1             6.6     23,614  Internet Movie Database  ...    True  False
# 3             6.8      7,804  Internet Movie Database  ...    True  False
# 5             4.9     32,329  Internet Movie Database  ...    True  False
# 8             7.9    237,103  Internet Movie Database  ...    True  False
# 10            6.5      9,498  Internet Movie Database  ...    True  False
# 11            5.5      3,521  Internet Movie Database  ...    True  False
# 13            7.5     51,513  Internet Movie Database  ...    True  False
# 14            5.1     76,719  Internet Movie Database  ...    True   True
# 16            6.0     81,928  Internet Movie Database  ...    True  False
# 17            5.5    164,922  Internet Movie Database  ...    True   True
# 19            5.6      4,366  Internet Movie Database  ...    True  False
# 22            4.6     17,027  Internet Movie Database  ...    True  False
# 23            5.5    129,422  Internet Movie Database  ...    True  False
# 24            6.1      8,854  Internet Movie Database  ...    True  False
# 26            7.3    164,273  Internet Movie Database  ...    True  False
# 27            6.3      1,449  Internet Movie Database  ...    True  False
# 35            6.1    185,093  Internet Movie Database  ...    True  False
# 36            5.2     11,833  Internet Movie Database  ...    True  False
# 38            5.3     92,790  Internet Movie Database  ...    True  False
# 39            5.7      8,925  Internet Movie Database  ...    True  False
# 40            5.0      9,464  Internet Movie Database  ...    True  False
# 41            6.6    211,245  Internet Movie Database  ...    True  False
# 42            7.0    295,621  Internet Movie Database  ...    True  False
# 44            4.4     45,929  Internet Movie Database  ...    True  False
# 45            7.7    267,148  Internet Movie Database  ...    True  False
# 46            6.8      5,104  Internet Movie Database  ...    True  False
# 53            6.6     54,798  Internet Movie Database  ...    True  False
# 58            8.3    729,083  Internet Movie Database  ...    True  False
# 60            6.7      7,131  Internet Movie Database  ...    True  False
# 70            6.4    181,897  Internet Movie Database  ...    True  False
# ...           ...        ...                      ...  ...     ...    ...
# 2685          3.2     49,847  Internet Movie Database  ...    True  False
# 2688          7.3     13,997  Internet Movie Database  ...    True  False
# 2696          5.4      4,999  Internet Movie Database  ...    True  False
# 2698          6.6     28,086  Internet Movie Database  ...    True  False
# 2700          6.9    165,357  Internet Movie Database  ...    True   True
# 2701          7.0    108,848  Internet Movie Database  ...    True  False
# 2707          5.8     23,568  Internet Movie Database  ...    True  False
# 2710          6.5     13,807  Internet Movie Database  ...    True  False
# 2711          6.8    237,263  Internet Movie Database  ...    True   True
# 2712          6.0     19,726  Internet Movie Database  ...    True   True
# 2714          6.7     44,355  Internet Movie Database  ...    True  False
# 2717          7.1    136,204  Internet Movie Database  ...    True   True
# 2720          6.1      5,256  Internet Movie Database  ...    True  False
# 2728          3.7      3,506  Internet Movie Database  ...    True  False
# 2735          7.9    503,786  Internet Movie Database  ...    True   True
# 2736          5.5     34,080  Internet Movie Database  ...    True  False
# 2737          6.9     19,505  Internet Movie Database  ...    True  False
# 2738          7.4    183,698  Internet Movie Database  ...    True  False
# 2740          6.0     50,842  Internet Movie Database  ...    True  False
# 2744          6.1      5,298  Internet Movie Database  ...    True  False
# 2749          7.0      9,582  Internet Movie Database  ...    True  False
# 2751          7.5    147,538  Internet Movie Database  ...    True  False
# 2753          6.7     41,519  Internet Movie Database  ...    True  False
# 2754          6.9    250,823  Internet Movie Database  ...    True   True
# 2756          5.8     46,752  Internet Movie Database  ...    True  False
# 2758          5.5     14,904  Internet Movie Database  ...    True  False
# 2771          6.5     28,883  Internet Movie Database  ...    True  False
# 2776          6.9    169,358  Internet Movie Database  ...    True   True
# 2787          7.8    413,301  Internet Movie Database  ...    True  False
# 2791          5.5    164,922  Internet Movie Database  ...    True   True
#
#       drama romance  thriller  adventure  crime  fantasy  family  scifi
# 1      True    True     False      False  False    False   False  False
# 3      True    True     False      False  False    False   False  False
# 5     False   False     False       True  False    False    True  False
# 8      True   False     False       True  False    False   False  False
# 10     True   False     False      False  False    False   False  False
# 11     True   False     False      False  False    False   False  False
# 13    False   False     False      False  False    False   False  False
# 14    False   False     False      False   True    False   False  False
# 16    False    True     False      False  False    False   False  False
# 17    False   False      True       True   True    False   False  False
# 19    False   False     False      False   True    False   False  False
# 22     True    True     False      False  False    False   False  False
# 23    False   False     False      False  False    False   False   True
# 24     True    True     False      False  False    False   False  False
# 26    False   False     False       True  False     True    True  False
# 27    False   False     False      False  False    False   False  False
# 35    False   False     False      False  False     True    True  False
# 36    False   False     False      False  False    False   False  False
# 38    False   False     False      False  False     True   False  False
# 39    False   False     False       True  False     True    True  False
# 40    False   False     False      False   True    False   False  False
# 41    False   False     False      False  False    False   False  False
# 42    False    True     False      False  False    False   False  False
# 44    False    True     False      False  False    False   False   True
# 45    False   False     False       True   True    False   False  False
# 46    False   False     False      False  False    False   False  False
# 53    False   False     False      False  False    False   False  False
# 58    False   False     False      False   True    False   False  False
# 60     True    True     False      False  False    False   False  False
# 70    False    True     False      False  False     True   False  False
# ...     ...     ...       ...        ...    ...      ...     ...    ...
# 2685  False   False     False       True  False     True    True  False
# 2688   True   False     False      False  False    False   False  False
# 2696  False   False     False       True  False     True    True  False
# 2698   True   False     False      False  False    False   False  False
# 2700  False   False      True      False  False    False   False  False
# 2701   True   False     False      False   True    False   False  False
# 2707   True    True     False      False  False    False   False  False
# 2710   True   False     False      False  False    False   False  False
# 2711  False   False     False       True  False    False   False  False
# 2712  False   False     False       True  False    False    True  False
# 2714   True   False     False      False  False    False   False  False
# 2717  False   False     False      False   True    False   False  False
# 2720   True   False      True       True  False     True    True   True
# 2728   True   False     False      False  False    False   False  False
# 2735  False   False     False       True  False     True   False   True
# 2736  False   False     False      False  False    False   False  False
# 2737   True   False     False      False  False    False   False  False
# 2738   True   False     False      False  False    False   False  False
# 2740  False   False     False      False  False    False   False  False
# 2744  False   False     False       True  False     True    True  False
# 2749   True   False     False      False  False    False   False  False
# 2751   True   False     False      False  False    False   False  False
# 2753  False   False     False       True  False     True    True  False
# 2754  False   False     False       True  False     True   False  False
# 2756  False   False     False      False  False    False   False  False
# 2758   True   False     False      False  False    False   False  False
# 2771  False   False     False       True  False     True    True  False
# 2776  False   False     False      False   True    False   False  False
# 2787   True   False     False      False  False    False   False  False
# 2791  False   False      True       True   True    False   False  False
#
# [1173 rows x 27 columns]

# %%
# get counts
comedy_count = comedy_loc["Title"].count()
action_count = action_loc["Title"].count()
drama_count = drama_loc["Title"].count()
romance_count = romance_loc["Title"].count()
thriller_count = thriller_loc["Title"].count()
adventure_count = adventure_loc["Title"].count()
crime_count = crime_loc["Title"].count()
fantasy_count = fantasy_loc["Title"].count()
family_count = family_loc["Title"].count()
scifi_count = scifi_loc["Title"].count()

# test one
comedy_count
# Out:
# 1173

# %%
# total movie count
total_movies = genre_df["Title"].count()
total_movies
# Out:
# 2792

# %%
# get average ratings
comedy_critic = comedy_loc["imdb_rating"].mean()
action_critic = action_loc["imdb_rating"].mean()
drama_critic = drama_loc["imdb_rating"].mean()
romance_critic = romance_loc["imdb_rating"].mean()
thriller_critic = thriller_loc["imdb_rating"].mean()
adventure_critic = adventure_loc["imdb_rating"].mean()
crime_critic = crime_loc["imdb_rating"].mean()
fantasy_critic = fantasy_loc["imdb_rating"].mean()
family_critic = family_loc["imdb_rating"].mean()
scifi_critic = scifi_loc["imdb_rating"].mean()

# test one
comedy_critic
# Out:
# 6.048849104859338

# %%
# get stats for each genre
# comedy
(comedy_slope, comedy_intercept, comedy_rvalue, comedy_pvalue, comedy_stderr) = linregress(comedy_loc["imdb_rating"], 
                                                                            comedy_loc["Box Office"])
comedy_regress = comedy_loc["imdb_rating"] * comedy_slope + comedy_intercept
comedy_rvalue = round(comedy_rvalue,2)

# action
(action_slope, action_intercept, action_rvalue, action_pvalue, action_stderr) = linregress(action_loc["imdb_rating"], 
                                                                                           action_loc["Box Office"])
action_regress = action_loc["imdb_rating"] * action_slope + action_intercept
action_rvalue = round(action_rvalue,2)

# drama
(drama_slope, drama_intercept, drama_rvalue, drama_pvalue, drama_stderr) = linregress(drama_loc["imdb_rating"], 
                                                                                           drama_loc["Box Office"])
drama_regress = drama_loc["imdb_rating"] * drama_slope + drama_intercept
drama_rvalue = round(drama_rvalue,2)

# romance
(romance_slope, romance_intercept, romance_rvalue, romance_pvalue, romance_stderr) = linregress(romance_loc["imdb_rating"], 
                                                                                           romance_loc["Box Office"])
romance_regress = romance_loc["imdb_rating"] * romance_slope + romance_intercept
romance_rvalue = round(romance_rvalue,2)

# thriller
(thriller_slope, thriller_intercept, thriller_rvalue, thriller_pvalue, thriller_stderr) = linregress(thriller_loc["imdb_rating"], 
                                                                                           thriller_loc["Box Office"])
thriller_regress = thriller_loc["imdb_rating"] * thriller_slope + thriller_intercept
thriller_rvalue = round(thriller_rvalue,2)

# adventure
(adventure_slope, adventure_intercept, adventure_rvalue, adventure_pvalue, adventure_stderr) = linregress(adventure_loc["imdb_rating"], 
                                                                                           adventure_loc["Box Office"])
adventure_regress = adventure_loc["imdb_rating"] * adventure_slope + adventure_intercept
adventure_rvalue = round(adventure_rvalue,2)

# crime
(crime_slope, crime_intercept, crime_rvalue, crime_pvalue, crime_stderr) = linregress(crime_loc["imdb_rating"], 
                                                                                           crime_loc["Box Office"])
crime_regress = crime_loc["imdb_rating"] * crime_slope + crime_intercept
crime_rvalue = round(crime_rvalue,2)

# fantasy
(fantasy_slope, fantasy_intercept, fantasy_rvalue, fantasy_pvalue, fantasy_stderr) = linregress(fantasy_loc["imdb_rating"], 
                                                                                           fantasy_loc["Box Office"])
fantasy_regress = fantasy_loc["imdb_rating"] * fantasy_slope + fantasy_intercept
fantasy_rvalue = round(fantasy_rvalue,2)

# family
(family_slope, family_intercept, family_rvalue, family_pvalue, family_stderr) = linregress(family_loc["imdb_rating"], 
                                                                                           family_loc["Box Office"])
family_regress = family_loc["imdb_rating"] * family_slope + family_intercept
family_rvalue = round(family_rvalue,2)

# scifi
(scifi_slope, scifi_intercept, scifi_rvalue, scifi_pvalue, scifi_stderr) = linregress(scifi_loc["imdb_rating"], 
                                                                                           scifi_loc["Box Office"])
family_scifi = scifi_loc["imdb_rating"] * scifi_slope + scifi_intercept
scifi_rvalue = round(scifi_rvalue,2)

# %%
# genre summary table lists
genre_list = ["comedy", "action", "drama", "romance", "thriller", "adventure", "crime", "fantasy", "family", "scifi"]
genre_count_list = [comedy_count,action_count,drama_count,romance_count,thriller_count,adventure_count,crime_count,
                    fantasy_count,family_count,scifi_count]
genre_perc_films = (genre_count_list / total_movies) * 100
genre_r_list = [comedy_rvalue,action_rvalue,drama_rvalue,romance_rvalue,thriller_rvalue,adventure_rvalue,crime_rvalue,
                    fantasy_rvalue,family_rvalue,scifi_rvalue]

# genre summary dataframe
genre_summary = pd.DataFrame({"Genre" : genre_list,
                              "Movie Count" : genre_count_list,
                              "Percent of Movies" : genre_perc_films,
                              "R-Sq Rating to Box Office" : genre_r_list})


# table formating and sorting
genre_summary = genre_summary.sort_values(by="R-Sq Rating to Box Office")
genre_summary["Percent of Movies"] = round(genre_summary["Percent of Movies"],2)
genre_summary
# Out:
#        Genre  Movie Count  Percent of Movies  R-Sq Rating to Box Office
# 3    romance          630              22.56                       0.03
# 2      drama         1424              51.00                       0.22
# 6      crime          492              17.62                       0.24
# 0     comedy         1173              42.01                       0.25
# 4   thriller          808              28.94                       0.34
# 7    fantasy          382              13.68                       0.41
# 1     action          659              23.60                       0.44
# 5  adventure          558              19.99                       0.44
# 9      scifi          336              12.03                       0.44
# 8     family          362              12.97                       0.47

# %%
# plot all r squared values
plt.barh(genre_summary["Genre"], genre_summary["R-Sq Rating to Box Office"], color="red")

# format chart
plt.title("Genre v Box Office R-Squared Values")
plt.xlabel("R-Squared")
plt.ylabel("Genre")

plt.tight_layout()
plt.show()

# %%
# plot comedy
plt.scatter(comedy_loc["imdb_rating"], comedy_loc["Box Office"], color="blue",edgecolors="black")
plt.plot(comedy_loc["imdb_rating"],comedy_regress,color="red")

# format chart
plt.title("Comedy Rating v Box Office")
plt.xlabel("IMDB Rating")
plt.ylabel("Box Office (M)")
plt.ylim(bottom=0)
plt.xlim(left=2)
plt.tight_layout()
plt.show()
print(f"R-squared is {comedy_rvalue}")
# Out:
# R-squared is 0.25

# %%
# plot romance
plt.scatter(romance_loc["imdb_rating"], romance_loc["Box Office"], color="blue",edgecolors="black")
plt.plot(romance_loc["imdb_rating"],romance_regress,color="red")

# format chart
plt.title("Romance Rating v Box Office")
plt.xlabel("IMDB Rating")
plt.ylabel("Box Office (M)")
plt.ylim(bottom=0)
plt.xlim(left=2)
plt.tight_layout()
plt.show()
print(f"R-squared is {romance_rvalue}")
# Out:
# R-squared is 0.03

# %%
# plot action
plt.scatter(action_loc["imdb_rating"], action_loc["Box Office"], color="green",edgecolors="black")
plt.plot(action_loc["imdb_rating"],action_regress,color="red")

# format chart
plt.title("Action Rating v Box Office")
plt.xlabel("IMDB Rating")
plt.ylabel("Box Office (M)")
plt.ylim(bottom=0)
plt.xlim(left=2)
plt.tight_layout()
plt.show()
print(f"R-squared is {action_rvalue}")
# Out:
# R-squared is 0.44

# %%
# plot family
plt.scatter(family_loc["imdb_rating"], family_loc["Box Office"], color="green",edgecolors="black")
plt.plot(family_loc["imdb_rating"],family_regress,color="red")

# format chart
plt.title("Family Rating v Box Office")
plt.xlabel("IMDB Rating")
plt.ylabel("Box Office (M)")
plt.ylim(bottom=0)
plt.xlim(left=2)
plt.tight_layout()
plt.show()
print(f"R-squared is {family_rvalue}")
# Out:
# R-squared is 0.47

# %%
# plot adventure
plt.scatter(adventure_loc["imdb_rating"], adventure_loc["Box Office"], color="green",edgecolors="black")
plt.plot(adventure_loc["imdb_rating"],adventure_regress,color="red")

# format chart
plt.title("Adventure Rating v Box Office")
plt.xlabel("IMDB Rating")
plt.ylabel("Box Office (M)")
plt.ylim(bottom=0)
plt.xlim(left=2)
plt.tight_layout()
plt.show()
print(f"R-squared is {adventure_rvalue}")
# Out:
# R-squared is 0.44

# %% [markdown]
# # Census Section
# ---
# * Source: Box Office Mojo, an IMDB company
# * Source: Organisation for Economic Co-operation and Development
# * Source: Bureau of Labor Statistics

# %%
# import economic indicators table
economic_df = pd.read_csv("Economy_Indicators.csv")
economic_df = economic_df.sort_values(by="Year")
economic_df
# Out:
#     Year  Total Gross (M) YOY Box Office Change  Tickets Sold (M)  \
# 19  1998           6949.0                  9.2%            1480.7
# 18  1999           7448.0                  7.2%            1465.2
# 17  2000           7661.0                  2.9%            1420.8
# 16  2001           8412.5                  9.8%            1487.3
# 15  2002           9155.1                  8.8%            1575.7
# 14  2003           9239.7                  0.9%            1532.3
# 13  2004           9380.5                  1.5%            1510.5
# 12  2005           8840.5                 -5.8%            1379.2
# 11  2006           9209.5                  4.2%            1406.0
# 10  2007           9663.8                  4.9%            1404.6
# 9   2008           9630.7                 -0.3%            1341.3
# 8   2009          10595.5                 10.0%            1412.7
# 7   2010          10565.6                 -0.3%            1339.1
# 6   2011          10174.2                 -3.7%            1283.0
# 5   2012          10837.6                  6.5%            1361.5
# 4   2013          10924.6                  0.8%            1343.7
# 3   2014          10361.3                 -5.2%            1268.2
# 2   2015          11129.4                  7.4%            1320.2
# 1   2016          11377.5                  2.2%            1315.3
# 0   2017          11072.2                 -2.7%            1234.4
#
#    YOY Ticket Change  Unemployment  DPI  Median HH Income
# 19              6.7%           4.5  5.7               5.1
# 18             -1.1%           4.2  3.2               4.7
# 17             -3.0%           4.0  4.7               3.2
# 16              4.7%           4.7  2.8               0.6
# 15              6.0%           5.8  3.4               0.4
# 14             -2.8%           6.0  2.6               2.1
# 13             -1.4%           5.5  3.1               2.3
# 12             -8.7%           5.1  1.3               4.5
# 11              2.0%           4.6  3.6               4.0
# 10             -0.1%           4.6  2.1               4.2
# 9              -4.5%           5.8  1.2               0.1
# 8               5.3%           9.3  0.2              -1.0
# 7              -5.2%           9.6  1.9              -1.0
# 6              -4.2%           8.9  2.1               1.6
# 5               6.1%           8.1  3.2               1.9
# 4              -1.3%           7.4 -1.1               5.0
# 3              -5.6%           6.2  3.7               0.1
# 2               4.1%           5.3  3.9               5.3
# 1              -0.4%           4.9  1.8               4.5
# 0              -6.2%           4.4  2.3               4.0

# %%
# change volues to floats
economic_df['YOY Box Office Change'] = economic_df['YOY Box Office Change'].str.replace('%', '').astype(float)
economic_df['YOY Ticket Change'] = economic_df['YOY Ticket Change'].str.replace('%', '').astype(float)

economic_df.dtypes
# Out:
# Year                       int64
# Total Gross (M)          float64
# YOY Box Office Change    float64
# Tickets Sold (M)         float64
# YOY Ticket Change        float64
# Unemployment             float64
# DPI                      float64
# Median HH Income         float64
# dtype: object

# %%
# compare move measures to economy measures
plt.plot(economic_df["Year"], economic_df["YOY Box Office Change"], color="blue",marker="o", label="Box Office")
# plt.plot(economic_df["Year"], economic_df["YOY Ticket Change"], color="green", marker="o", label="Tickets") ##removed
plt.plot(economic_df["Year"], economic_df["DPI"], color="red", linestyle="--", label="DPI")

# format chart
plt.legend(loc="best")
plt.title("DPI v Box Office")
plt.xlabel("Year")
plt.ylabel("DPI (YOY Chg)")
plt.ylim(bottom=-10, top=12)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# compare move measures to economy measures
plt.plot(economic_df["Year"], economic_df["YOY Box Office Change"], color="blue",marker="o", label="Box Office")
plt.plot(economic_df["Year"], economic_df["Unemployment"], color="red", linestyle="--", label="Unemployment")

# format chart
plt.legend(loc="best")
plt.title("Unemployment v Box Office")
plt.xlabel("Year")
plt.ylabel("Unemployment")
plt.ylim(bottom=-10, top=12)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# compare move measures to economy measures
plt.plot(economic_df["Year"], economic_df["YOY Box Office Change"], color="blue",marker="o", label="Box Office")
plt.plot(economic_df["Year"], economic_df["Median HH Income"], color="red", linestyle="--", label="Median HH Income")

# format chart
plt.legend(loc="best")
plt.title("Median HH Income v Box Office")
plt.xlabel("Year")
plt.ylabel("Median HH Income (YOY)")
plt.ylim(bottom=-10, top=12)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
